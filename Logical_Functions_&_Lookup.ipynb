# %% [markdown]
# # Logical Functions & Lookup
#
# 1. Write a formula to check if the marks in cell are greater than or equal to 40. If yes, return , otherwise
#
# - =IF(B3>=40,"pass","fail")
#
# 2.  company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a
# formula to calculate whether the employee will get a bonus or not .
#
# - =IF(AND(G3>40000,H3>=90),"BONUS","NO-BONUS")
#
# 3.Write a nested IF formula:If marks in are ≥ 90 → , ≥ 75 → , ≥ 50 → , otherwise . B2 "A" "B" "C" "Fail.
#
# - =IFS(B11>=90,"A",B11>=75,"B",B11>=50,"C",TRUE,"Fail")
#
# 4. nd the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
#
# - Department of Employee ID = E103 is Finance and the formula used to retrieve this value is =VLOOKUP(F13,F13:H16,3,0) as the VLOOKUP function is suitable here because the unique identifier, EmpID ("E103"), is in the first column of the data table, and the information to be retrieved (Department) is in a subsequent column.
#
# 5. Company has set the following commission structure for its sales team.If a salesperson achieves sales of ₹45,000, use the VLOOKUP function to determine the commission rate
# applicable.
#
# - salesperson who achieves sales of ₹45,000 will get the commission rate applicable is 10% by using the formula - =VLOOKUP(A20,A20:B23,2,0).
#
# 6. The HR department maintains the following leave records of employees:onus or not .Write an IF function to check whether an employee has Exceeded their allowed leave balance.
#
# If Leaves Taken > Allowed Leaves, display "Exceeded".
#
# Otherwise, display "OK".
#
# - =IF(I19>J19,"Exceeded","OK")
#
# 7. Find the salary of EmpID = E105 using INDEX-MATCH Function.
#
# - the salary of EmpID = E105 using INDEX-MATCH Function is 72000 by using formula as ==INDEX(B27:B30,MATCH(B27,B27:B30,0)).
#
# 8. Use the XLOOKUP function to find the Department of the employee with Emp ID = E303
#
# -  Using the XLOOKUP function the value of the Department of the employee with Emp ID = E303 is IT with formula as =XLOOKUP(A34,A34:A37,B34:B37,"not present",0,1).
